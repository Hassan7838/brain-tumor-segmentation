# %%
# Import Necessary Libraries

import os
import h5py
import numpy as np
import matplotlib.pyplot as plt
from tqdm import tqdm
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras import layers, Model, backend as K

# %%
# Data Loading

DATA_PATH = "/kaggle/input/brats2020-training-data/BraTS2020_training_data/content/data"
MAX_FILES = 2000

def safe_load_h5(path):
    try:
        with h5py.File(path, 'r') as f:
            img = np.array(f['image']).astype(np.float32)
            msk = np.array(f['mask']).astype(np.float32)
            return img, msk
    except Exception as e:
        return None, None

print("Loading dataset...")
files = sorted([f for f in os.listdir(DATA_PATH) if f.endswith('.h5')])[:MAX_FILES]

images = []
masks = []

for fname in tqdm(files, desc="Loading files"):
    p = os.path.join(DATA_PATH, fname)
    img, msk = safe_load_h5(p)
    if img is None:
        continue
        
    if img.ndim == 2:
        img = np.expand_dims(img, -1)
    if msk.ndim == 2:
        msk = np.expand_dims(msk, -1)

    # Normalize image
    p99 = np.percentile(img, 99)
    img_norm = img / p99 if p99 > 0 else img
    img_norm = np.clip(img_norm, 0.0, 1.0)

    # Mask processing
    msk = np.clip(msk, 0.0, 1.0)

    images.append(img_norm)
    masks.append(msk)

X = np.array(images, dtype=np.float32)
Y = np.array(masks, dtype=np.float32)
print(f"Loaded shapes -> X: {X.shape}, Y: {Y.shape}")
# Out:
# Loading dataset...
# Loading files: 100%|██████████| 2000/2000 [00:36<00:00, 54.79it/s]
# Loaded shapes -> X: (2000, 240, 240, 4), Y: (2000, 240, 240, 3)

# %%
# Loss Functions

def dice_coef(y_true, y_pred, smooth=1e-6):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (2. * intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) + smooth)

def dice_loss(y_true, y_pred):
    return 1 - dice_coef(y_true, y_pred)

def combined_loss(y_true, y_pred):
    bce = tf.keras.losses.binary_crossentropy(y_true, y_pred)
    bce = K.mean(bce)
    d_loss = dice_loss(y_true, y_pred)
    return bce + d_loss

# %%
# 3-Channel U-Net

def build_simple_multi_unet(input_shape=(240, 240, 4), num_classes=3):
    """U-Net that works well"""
    inputs = tf.keras.Input(shape=input_shape)
    
    # Downsample
    c1 = layers.Conv2D(32, 3, activation='relu', padding='same')(inputs)
    c1 = layers.Conv2D(32, 3, activation='relu', padding='same')(c1)
    p1 = layers.MaxPooling2D(2)(c1)
    
    c2 = layers.Conv2D(64, 3, activation='relu', padding='same')(p1)
    c2 = layers.Conv2D(64, 3, activation='relu', padding='same')(c2)
    p2 = layers.MaxPooling2D(2)(c2)
    
    # Bottleneck
    c3 = layers.Conv2D(128, 3, activation='relu', padding='same')(p2)
    c3 = layers.Conv2D(128, 3, activation='relu', padding='same')(c3)
    
    # Upsample
    u1 = layers.UpSampling2D(2)(c3)
    u1 = layers.concatenate([u1, c2])
    c4 = layers.Conv2D(64, 3, activation='relu', padding='same')(u1)
    c4 = layers.Conv2D(64, 3, activation='relu', padding='same')(c4)
    
    u2 = layers.UpSampling2D(2)(c4)
    u2 = layers.concatenate([u2, c1])
    c5 = layers.Conv2D(32, 3, activation='relu', padding='same')(u2)
    c5 = layers.Conv2D(32, 3, activation='relu', padding='same')(c5)
    
    # 3 output channels with sigmoid (independent segmentation)
    outputs = layers.Conv2D(num_classes, 1, activation='sigmoid')(c5)
    
    model = tf.keras.Model(inputs, outputs)
    return model

# %%
# Train/Val Split

X_train, X_val, y_train, y_val = train_test_split(X, Y, test_size=0.18, random_state=42)
print(f"Train: {X_train.shape}, {y_train.shape}")
print(f"Val: {X_val.shape}, {y_val.shape}")
# Out:
# Train: (1640, 240, 240, 4), (1640, 240, 240, 3)
# Val: (360, 240, 240, 4), (360, 240, 240, 3)

# %%
# Build & Compile Model

print("Building 3-channel U-Net...")
model = build_simple_multi_unet(input_shape=X_train.shape[1:], num_classes=3)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-4),
    loss=combined_loss,
    metrics=['accuracy', dice_coef]
)

model.summary()
# Out:
# Building 3-channel U-Net...
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 240, 240,  │          0 │ -                 │
# │ (InputLayer)        │ 4)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 240, 240,  │      1,184 │ input_layer_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 240, 240,  │      9,248 │ conv2d_11[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 120, 120,  │          0 │ conv2d_12[0][0]   │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 120, 120,  │     18,496 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 120, 120,  │     36,928 │ conv2d_13[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 60, 60,    │          0 │ conv2d_14[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_15 (Conv2D)  │ (None, 60, 60,    │     73,856 │ max_pooling2d_3[… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_16 (Conv2D)  │ (None, 60, 60,    │    147,584 │ conv2d_15[0][0]   │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_2     │ (None, 120, 120,  │          0 │ conv2d_16[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_2       │ (None, 120, 120,  │          0 │ up_sampling2d_2[… │
# │ (Concatenate)       │ 192)              │            │ conv2d_14[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_17 (Conv2D)  │ (None, 120, 120,  │    110,656 │ concatenate_2[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_18 (Conv2D)  │ (None, 120, 120,  │     36,928 │ conv2d_17[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_3     │ (None, 240, 240,  │          0 │ conv2d_18[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_3       │ (None, 240, 240,  │          0 │ up_sampling2d_3[… │
# │ (Concatenate)       │ 96)               │            │ conv2d_12[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_19 (Conv2D)  │ (None, 240, 240,  │     27,680 │ concatenate_3[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_20 (Conv2D)  │ (None, 240, 240,  │      9,248 │ conv2d_19[0][0]   │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_21 (Conv2D)  │ (None, 240, 240,  │         99 │ conv2d_20[0][0]   │
# │                     │ 3)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 471,907 (1.80 MB)
#  Trainable params: 471,907 (1.80 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Callbacks

callbacks = [
    tf.keras.callbacks.ReduceLROnPlateau(monitor='val_dice_coef', factor=0.5, patience=10, min_lr=1e-7, mode='max'),
    tf.keras.callbacks.EarlyStopping(monitor='val_dice_coef', patience=20, restore_best_weights=True, mode='max'),
    tf.keras.callbacks.ModelCheckpoint('best_multi_model.h5', monitor='val_dice_coef', save_best_only=True, mode='max')
]

# %%
# Training

print("Starting training with 3-channel model...")
history = model.fit(
    X_train, y_train,
    batch_size=8,
    epochs=100,  
    validation_data=(X_val, y_val),
    callbacks=callbacks,
    shuffle=True,
    verbose=1
)
# Out:
# Starting training with 3-channel model...
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1760553741.580857     109 service.cc:148] XLA service 0x7d5e9004c290 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1760553741.581646     109 service.cc:156]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1760553741.581668     109 service.cc:156]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1760553742.330106     109 cuda_dnn.cc:529] Loaded cuDNN version 90300
#   1/205 ━━━━━━━━━━━━━━━━━━━━ 1:02:42 18s/step - accuracy: 0.6670 - dice_coef: 0.0036 - loss: 1.6923
# I0000 00:00:1760553755.055792     109 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 45s 130ms/step - accuracy: 0.0271 - dice_coef: 0.0254 - loss: 1.2943 - val_accuracy: 0.0042 - val_dice_coef: 0.3031 - val_loss: 0.7064 - learning_rate: 1.0000e-04
# Epoch 2/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 109ms/step - accuracy: 0.0043 - dice_coef: 0.3733 - loss: 0.6405 - val_accuracy: 0.0039 - val_dice_coef: 0.3514 - val_loss: 0.6712 - learning_rate: 1.0000e-04
# Epoch 3/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 108ms/step - accuracy: 0.0044 - dice_coef: 0.4465 - loss: 0.5686 - val_accuracy: 0.0039 - val_dice_coef: 0.2930 - val_loss: 0.7360 - learning_rate: 1.0000e-04
# Epoch 4/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0040 - dice_coef: 0.4503 - loss: 0.5638 - val_accuracy: 0.0043 - val_dice_coef: 0.4588 - val_loss: 0.5569 - learning_rate: 1.0000e-04
# Epoch 5/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0054 - dice_coef: 0.5313 - loss: 0.4800 - val_accuracy: 0.0055 - val_dice_coef: 0.5025 - val_loss: 0.5131 - learning_rate: 1.0000e-04
# Epoch 6/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 107ms/step - accuracy: 0.0080 - dice_coef: 0.5880 - loss: 0.4215 - val_accuracy: 0.1684 - val_dice_coef: 0.6032 - val_loss: 0.4059 - learning_rate: 1.0000e-04
# Epoch 7/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 107ms/step - accuracy: 0.7475 - dice_coef: 0.6523 - loss: 0.3545 - val_accuracy: 0.9809 - val_dice_coef: 0.6075 - val_loss: 0.4023 - learning_rate: 1.0000e-04
# Epoch 8/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.9681 - dice_coef: 0.6627 - loss: 0.3437 - val_accuracy: 0.9619 - val_dice_coef: 0.6690 - val_loss: 0.3378 - learning_rate: 1.0000e-04
# Epoch 9/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.9559 - dice_coef: 0.6957 - loss: 0.3108 - val_accuracy: 0.9514 - val_dice_coef: 0.6862 - val_loss: 0.3206 - learning_rate: 1.0000e-04
# Epoch 10/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 107ms/step - accuracy: 0.9380 - dice_coef: 0.7146 - loss: 0.2922 - val_accuracy: 0.9110 - val_dice_coef: 0.7191 - val_loss: 0.2874 - learning_rate: 1.0000e-04
# Epoch 11/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.9435 - dice_coef: 0.7256 - loss: 0.2805 - val_accuracy: 0.9293 - val_dice_coef: 0.6697 - val_loss: 0.3371 - learning_rate: 1.0000e-04
# Epoch 12/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.9532 - dice_coef: 0.7528 - loss: 0.2526 - val_accuracy: 0.9541 - val_dice_coef: 0.7334 - val_loss: 0.2729 - learning_rate: 1.0000e-04
# Epoch 13/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.9589 - dice_coef: 0.7674 - loss: 0.2381 - val_accuracy: 0.9653 - val_dice_coef: 0.7184 - val_loss: 0.2884 - learning_rate: 1.0000e-04
# Epoch 14/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.9563 - dice_coef: 0.7806 - loss: 0.2243 - val_accuracy: 0.9569 - val_dice_coef: 0.7589 - val_loss: 0.2461 - learning_rate: 1.0000e-04
# Epoch 15/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.8455 - dice_coef: 0.7665 - loss: 0.2383 - val_accuracy: 0.1189 - val_dice_coef: 0.7590 - val_loss: 0.2459 - learning_rate: 1.0000e-04
# Epoch 16/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.1139 - dice_coef: 0.7810 - loss: 0.2243 - val_accuracy: 0.9426 - val_dice_coef: 0.7722 - val_loss: 0.2320 - learning_rate: 1.0000e-04
# Epoch 17/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.4743 - dice_coef: 0.7917 - loss: 0.2119 - val_accuracy: 0.2751 - val_dice_coef: 0.7692 - val_loss: 0.2360 - learning_rate: 1.0000e-04
# Epoch 18/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.1805 - dice_coef: 0.8165 - loss: 0.1873 - val_accuracy: 0.0115 - val_dice_coef: 0.7828 - val_loss: 0.2215 - learning_rate: 1.0000e-04
# Epoch 19/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0501 - dice_coef: 0.7741 - loss: 0.2299 - val_accuracy: 0.0803 - val_dice_coef: 0.7047 - val_loss: 0.3024 - learning_rate: 1.0000e-04
# Epoch 20/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0716 - dice_coef: 0.7880 - loss: 0.2164 - val_accuracy: 0.0677 - val_dice_coef: 0.7965 - val_loss: 0.2076 - learning_rate: 1.0000e-04
# Epoch 21/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0800 - dice_coef: 0.8233 - loss: 0.1807 - val_accuracy: 0.0810 - val_dice_coef: 0.7781 - val_loss: 0.2268 - learning_rate: 1.0000e-04
# Epoch 22/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0687 - dice_coef: 0.7818 - loss: 0.2218 - val_accuracy: 0.0672 - val_dice_coef: 0.7833 - val_loss: 0.2215 - learning_rate: 1.0000e-04
# Epoch 23/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0616 - dice_coef: 0.8076 - loss: 0.1964 - val_accuracy: 0.0651 - val_dice_coef: 0.7875 - val_loss: 0.2170 - learning_rate: 1.0000e-04
# Epoch 24/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0488 - dice_coef: 0.8136 - loss: 0.1898 - val_accuracy: 0.0074 - val_dice_coef: 0.7881 - val_loss: 0.2167 - learning_rate: 1.0000e-04
# Epoch 25/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0477 - dice_coef: 0.7854 - loss: 0.2181 - val_accuracy: 0.0257 - val_dice_coef: 0.7963 - val_loss: 0.2080 - learning_rate: 1.0000e-04
# Epoch 26/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0620 - dice_coef: 0.8232 - loss: 0.1799 - val_accuracy: 0.0285 - val_dice_coef: 0.8005 - val_loss: 0.2039 - learning_rate: 1.0000e-04
# Epoch 27/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.1006 - dice_coef: 0.8263 - loss: 0.1776 - val_accuracy: 0.0582 - val_dice_coef: 0.8082 - val_loss: 0.1959 - learning_rate: 1.0000e-04
# Epoch 28/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0722 - dice_coef: 0.8333 - loss: 0.1700 - val_accuracy: 0.0652 - val_dice_coef: 0.8117 - val_loss: 0.1923 - learning_rate: 1.0000e-04
# Epoch 29/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0505 - dice_coef: 0.8034 - loss: 0.1999 - val_accuracy: 0.0493 - val_dice_coef: 0.8144 - val_loss: 0.1893 - learning_rate: 1.0000e-04
# Epoch 30/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0485 - dice_coef: 0.8328 - loss: 0.1707 - val_accuracy: 0.0141 - val_dice_coef: 0.8186 - val_loss: 0.1853 - learning_rate: 1.0000e-04
# Epoch 31/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0491 - dice_coef: 0.7795 - loss: 0.2238 - val_accuracy: 0.0215 - val_dice_coef: 0.8290 - val_loss: 0.1746 - learning_rate: 1.0000e-04
# Epoch 32/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0258 - dice_coef: 0.8268 - loss: 0.1761 - val_accuracy: 0.0162 - val_dice_coef: 0.8278 - val_loss: 0.1757 - learning_rate: 1.0000e-04
# Epoch 33/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0575 - dice_coef: 0.8246 - loss: 0.1789 - val_accuracy: 0.0880 - val_dice_coef: 0.7951 - val_loss: 0.2098 - learning_rate: 1.0000e-04
# Epoch 34/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0483 - dice_coef: 0.8026 - loss: 0.2009 - val_accuracy: 0.0480 - val_dice_coef: 0.8330 - val_loss: 0.1704 - learning_rate: 1.0000e-04
# Epoch 35/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0173 - dice_coef: 0.7746 - loss: 0.2303 - val_accuracy: 0.0082 - val_dice_coef: 0.8158 - val_loss: 0.1877 - learning_rate: 1.0000e-04
# Epoch 36/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0118 - dice_coef: 0.8437 - loss: 0.1596 - val_accuracy: 0.0146 - val_dice_coef: 0.8155 - val_loss: 0.1883 - learning_rate: 1.0000e-04
# Epoch 37/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0670 - dice_coef: 0.8322 - loss: 0.1715 - val_accuracy: 0.0260 - val_dice_coef: 0.8173 - val_loss: 0.1866 - learning_rate: 1.0000e-04
# Epoch 38/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0663 - dice_coef: 0.8299 - loss: 0.1737 - val_accuracy: 0.0091 - val_dice_coef: 0.8359 - val_loss: 0.1676 - learning_rate: 1.0000e-04
# Epoch 39/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0130 - dice_coef: 0.8622 - loss: 0.1409 - val_accuracy: 0.0193 - val_dice_coef: 0.8261 - val_loss: 0.1773 - learning_rate: 1.0000e-04
# Epoch 40/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - accuracy: 0.3697 - dice_coef: 0.7568 - loss: 0.2539 - val_accuracy: 0.0084 - val_dice_coef: 0.8283 - val_loss: 0.1749 - learning_rate: 1.0000e-04
# Epoch 41/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - accuracy: 0.1636 - dice_coef: 0.8080 - loss: 0.1951 - val_accuracy: 0.0074 - val_dice_coef: 0.8354 - val_loss: 0.1679 - learning_rate: 1.0000e-04
# Epoch 42/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0185 - dice_coef: 0.8390 - loss: 0.1637 - val_accuracy: 0.0073 - val_dice_coef: 0.8355 - val_loss: 0.1677 - learning_rate: 1.0000e-04
# Epoch 43/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0264 - dice_coef: 0.8651 - loss: 0.1379 - val_accuracy: 0.0086 - val_dice_coef: 0.8498 - val_loss: 0.1534 - learning_rate: 1.0000e-04
# Epoch 44/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0085 - dice_coef: 0.8672 - loss: 0.1357 - val_accuracy: 0.0084 - val_dice_coef: 0.8483 - val_loss: 0.1548 - learning_rate: 1.0000e-04
# Epoch 45/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0269 - dice_coef: 0.8220 - loss: 0.1811 - val_accuracy: 0.0077 - val_dice_coef: 0.8420 - val_loss: 0.1613 - learning_rate: 1.0000e-04
# Epoch 46/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0080 - dice_coef: 0.8463 - loss: 0.1570 - val_accuracy: 0.0086 - val_dice_coef: 0.8417 - val_loss: 0.1618 - learning_rate: 1.0000e-04
# Epoch 47/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0091 - dice_coef: 0.8276 - loss: 0.1752 - val_accuracy: 0.0211 - val_dice_coef: 0.8446 - val_loss: 0.1590 - learning_rate: 1.0000e-04
# Epoch 48/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0525 - dice_coef: 0.7735 - loss: 0.2314 - val_accuracy: 0.0110 - val_dice_coef: 0.8366 - val_loss: 0.1668 - learning_rate: 1.0000e-04
# Epoch 49/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0135 - dice_coef: 0.8396 - loss: 0.1632 - val_accuracy: 0.0156 - val_dice_coef: 0.8518 - val_loss: 0.1513 - learning_rate: 1.0000e-04
# Epoch 50/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0309 - dice_coef: 0.8563 - loss: 0.1463 - val_accuracy: 0.0109 - val_dice_coef: 0.8444 - val_loss: 0.1588 - learning_rate: 1.0000e-04
# Epoch 51/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0154 - dice_coef: 0.8400 - loss: 0.1626 - val_accuracy: 0.0190 - val_dice_coef: 0.8533 - val_loss: 0.1498 - learning_rate: 1.0000e-04
# Epoch 52/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0155 - dice_coef: 0.8872 - loss: 0.1155 - val_accuracy: 0.0108 - val_dice_coef: 0.8566 - val_loss: 0.1463 - learning_rate: 1.0000e-04
# Epoch 53/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0116 - dice_coef: 0.8683 - loss: 0.1341 - val_accuracy: 0.0170 - val_dice_coef: 0.8250 - val_loss: 0.1790 - learning_rate: 1.0000e-04
# Epoch 54/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0196 - dice_coef: 0.8752 - loss: 0.1275 - val_accuracy: 0.0091 - val_dice_coef: 0.8524 - val_loss: 0.1507 - learning_rate: 1.0000e-04
# Epoch 55/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0093 - dice_coef: 0.8293 - loss: 0.1734 - val_accuracy: 0.0131 - val_dice_coef: 0.8518 - val_loss: 0.1511 - learning_rate: 1.0000e-04
# Epoch 56/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0102 - dice_coef: 0.8567 - loss: 0.1461 - val_accuracy: 0.0100 - val_dice_coef: 0.8580 - val_loss: 0.1450 - learning_rate: 1.0000e-04
# Epoch 57/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0145 - dice_coef: 0.8637 - loss: 0.1390 - val_accuracy: 0.0285 - val_dice_coef: 0.8398 - val_loss: 0.1635 - learning_rate: 1.0000e-04
# Epoch 58/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0167 - dice_coef: 0.8848 - loss: 0.1177 - val_accuracy: 0.0163 - val_dice_coef: 0.8604 - val_loss: 0.1424 - learning_rate: 1.0000e-04
# Epoch 59/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0125 - dice_coef: 0.8503 - loss: 0.1525 - val_accuracy: 0.0120 - val_dice_coef: 0.8530 - val_loss: 0.1501 - learning_rate: 1.0000e-04
# Epoch 60/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0417 - dice_coef: 0.8608 - loss: 0.1427 - val_accuracy: 0.0281 - val_dice_coef: 0.8503 - val_loss: 0.1526 - learning_rate: 1.0000e-04
# Epoch 61/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0380 - dice_coef: 0.8398 - loss: 0.1627 - val_accuracy: 0.6962 - val_dice_coef: 0.8467 - val_loss: 0.1565 - learning_rate: 1.0000e-04
# Epoch 62/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - accuracy: 0.3468 - dice_coef: 0.8545 - loss: 0.1482 - val_accuracy: 0.0624 - val_dice_coef: 0.8530 - val_loss: 0.1498 - learning_rate: 1.0000e-04
# Epoch 63/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0532 - dice_coef: 0.8826 - loss: 0.1198 - val_accuracy: 0.0183 - val_dice_coef: 0.8535 - val_loss: 0.1494 - learning_rate: 1.0000e-04
# Epoch 64/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0291 - dice_coef: 0.8823 - loss: 0.1200 - val_accuracy: 0.0515 - val_dice_coef: 0.8568 - val_loss: 0.1461 - learning_rate: 1.0000e-04
# Epoch 65/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0906 - dice_coef: 0.8842 - loss: 0.1181 - val_accuracy: 0.0203 - val_dice_coef: 0.8526 - val_loss: 0.1505 - learning_rate: 1.0000e-04
# Epoch 66/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - accuracy: 0.1861 - dice_coef: 0.8845 - loss: 0.1179 - val_accuracy: 0.0264 - val_dice_coef: 0.8593 - val_loss: 0.1439 - learning_rate: 1.0000e-04
# Epoch 67/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 21s 104ms/step - accuracy: 0.1797 - dice_coef: 0.8460 - loss: 0.1572 - val_accuracy: 0.7520 - val_dice_coef: 0.8062 - val_loss: 0.1982 - learning_rate: 1.0000e-04
# Epoch 68/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.2154 - dice_coef: 0.8576 - loss: 0.1451 - val_accuracy: 0.0312 - val_dice_coef: 0.8778 - val_loss: 0.1248 - learning_rate: 1.0000e-04
# Epoch 69/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0435 - dice_coef: 0.8502 - loss: 0.1518 - val_accuracy: 0.0335 - val_dice_coef: 0.8755 - val_loss: 0.1272 - learning_rate: 1.0000e-04
# Epoch 70/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0216 - dice_coef: 0.8717 - loss: 0.1305 - val_accuracy: 0.0127 - val_dice_coef: 0.8784 - val_loss: 0.1243 - learning_rate: 1.0000e-04
# Epoch 71/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 21s 105ms/step - accuracy: 0.0334 - dice_coef: 0.8855 - loss: 0.1167 - val_accuracy: 0.0548 - val_dice_coef: 0.8781 - val_loss: 0.1246 - learning_rate: 1.0000e-04
# Epoch 72/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0484 - dice_coef: 0.8908 - loss: 0.1113 - val_accuracy: 0.0178 - val_dice_coef: 0.8665 - val_loss: 0.1363 - learning_rate: 1.0000e-04
# Epoch 73/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0147 - dice_coef: 0.8917 - loss: 0.1105 - val_accuracy: 0.0262 - val_dice_coef: 0.8794 - val_loss: 0.1233 - learning_rate: 1.0000e-04
# Epoch 74/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.1245 - dice_coef: 0.8514 - loss: 0.1509 - val_accuracy: 0.0093 - val_dice_coef: 0.8786 - val_loss: 0.1240 - learning_rate: 1.0000e-04
# Epoch 75/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0157 - dice_coef: 0.8885 - loss: 0.1140 - val_accuracy: 0.0449 - val_dice_coef: 0.8797 - val_loss: 0.1229 - learning_rate: 1.0000e-04
# Epoch 76/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0362 - dice_coef: 0.8664 - loss: 0.1357 - val_accuracy: 0.0244 - val_dice_coef: 0.8787 - val_loss: 0.1239 - learning_rate: 1.0000e-04
# Epoch 77/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0198 - dice_coef: 0.8838 - loss: 0.1184 - val_accuracy: 0.0174 - val_dice_coef: 0.8793 - val_loss: 0.1234 - learning_rate: 1.0000e-04
# Epoch 78/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.1993 - dice_coef: 0.8432 - loss: 0.1602 - val_accuracy: 0.0130 - val_dice_coef: 0.8754 - val_loss: 0.1274 - learning_rate: 1.0000e-04
# Epoch 79/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0155 - dice_coef: 0.8868 - loss: 0.1155 - val_accuracy: 0.0242 - val_dice_coef: 0.8673 - val_loss: 0.1357 - learning_rate: 1.0000e-04
# Epoch 80/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0339 - dice_coef: 0.8660 - loss: 0.1361 - val_accuracy: 0.0530 - val_dice_coef: 0.8781 - val_loss: 0.1247 - learning_rate: 1.0000e-04
# Epoch 81/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0433 - dice_coef: 0.8838 - loss: 0.1183 - val_accuracy: 0.0204 - val_dice_coef: 0.8832 - val_loss: 0.1193 - learning_rate: 1.0000e-04
# Epoch 82/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0255 - dice_coef: 0.9006 - loss: 0.1016 - val_accuracy: 0.0200 - val_dice_coef: 0.8830 - val_loss: 0.1197 - learning_rate: 1.0000e-04
# Epoch 83/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0209 - dice_coef: 0.8651 - loss: 0.1379 - val_accuracy: 0.0345 - val_dice_coef: 0.8280 - val_loss: 0.1759 - learning_rate: 1.0000e-04
# Epoch 84/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0244 - dice_coef: 0.8810 - loss: 0.1211 - val_accuracy: 0.0206 - val_dice_coef: 0.8803 - val_loss: 0.1223 - learning_rate: 1.0000e-04
# Epoch 85/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0268 - dice_coef: 0.8567 - loss: 0.1460 - val_accuracy: 0.0442 - val_dice_coef: 0.8765 - val_loss: 0.1262 - learning_rate: 1.0000e-04
# Epoch 86/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0369 - dice_coef: 0.9010 - loss: 0.1010 - val_accuracy: 0.0288 - val_dice_coef: 0.8832 - val_loss: 0.1192 - learning_rate: 1.0000e-04
# Epoch 87/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0196 - dice_coef: 0.8522 - loss: 0.1499 - val_accuracy: 0.0269 - val_dice_coef: 0.8858 - val_loss: 0.1166 - learning_rate: 1.0000e-04
# Epoch 88/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0198 - dice_coef: 0.9006 - loss: 0.1014 - val_accuracy: 0.0128 - val_dice_coef: 0.8816 - val_loss: 0.1209 - learning_rate: 1.0000e-04
# Epoch 89/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0183 - dice_coef: 0.8766 - loss: 0.1254 - val_accuracy: 0.0190 - val_dice_coef: 0.8862 - val_loss: 0.1163 - learning_rate: 1.0000e-04
# Epoch 90/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0196 - dice_coef: 0.8882 - loss: 0.1138 - val_accuracy: 0.0167 - val_dice_coef: 0.8689 - val_loss: 0.1342 - learning_rate: 1.0000e-04
# Epoch 91/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0172 - dice_coef: 0.8767 - loss: 0.1255 - val_accuracy: 0.0277 - val_dice_coef: 0.8891 - val_loss: 0.1133 - learning_rate: 1.0000e-04
# Epoch 92/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0311 - dice_coef: 0.9008 - loss: 0.1013 - val_accuracy: 0.0146 - val_dice_coef: 0.8739 - val_loss: 0.1290 - learning_rate: 1.0000e-04
# Epoch 93/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0182 - dice_coef: 0.9002 - loss: 0.1018 - val_accuracy: 0.0169 - val_dice_coef: 0.8897 - val_loss: 0.1127 - learning_rate: 1.0000e-04
# Epoch 94/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0191 - dice_coef: 0.9034 - loss: 0.0983 - val_accuracy: 0.0117 - val_dice_coef: 0.8798 - val_loss: 0.1231 - learning_rate: 1.0000e-04
# Epoch 95/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0182 - dice_coef: 0.8597 - loss: 0.1439 - val_accuracy: 0.0455 - val_dice_coef: 0.8590 - val_loss: 0.1441 - learning_rate: 1.0000e-04
# Epoch 96/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0455 - dice_coef: 0.8824 - loss: 0.1199 - val_accuracy: 0.0334 - val_dice_coef: 0.8823 - val_loss: 0.1201 - learning_rate: 1.0000e-04
# Epoch 97/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0417 - dice_coef: 0.8640 - loss: 0.1380 - val_accuracy: 0.0436 - val_dice_coef: 0.8820 - val_loss: 0.1207 - learning_rate: 1.0000e-04
# Epoch 98/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0612 - dice_coef: 0.8655 - loss: 0.1370 - val_accuracy: 0.0155 - val_dice_coef: 0.8780 - val_loss: 0.1249 - learning_rate: 1.0000e-04
# Epoch 99/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 105ms/step - accuracy: 0.0199 - dice_coef: 0.8770 - loss: 0.1254 - val_accuracy: 0.1001 - val_dice_coef: 0.8202 - val_loss: 0.1843 - learning_rate: 1.0000e-04
# Epoch 100/100
# 205/205 ━━━━━━━━━━━━━━━━━━━━ 22s 106ms/step - accuracy: 0.0597 - dice_coef: 0.8984 - loss: 0.1042 - val_accuracy: 0.0342 - val_dice_coef: 0.8897 - val_loss: 0.1127 - learning_rate: 1.0000e-04

# %%
# Evaluation Matrices

from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Enhanced metrics functions
def iou_coef(y_true, y_pred, smooth=1e-6):
    """Intersection over Union (Jaccard Index)"""
    intersection = tf.reduce_sum(tf.abs(y_true * y_pred), axis=[1,2,3])
    union = tf.reduce_sum(y_true, axis=[1,2,3]) + tf.reduce_sum(y_pred, axis=[1,2,3]) - intersection
    iou = tf.reduce_mean((intersection + smooth) / (union + smooth))
    return iou

def precision_metric(y_true, y_pred):
    """Precision metric"""
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    predicted_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + tf.keras.backend.epsilon())
    return precision

def recall_metric(y_true, y_pred):
    """Recall metric (Sensitivity)"""
    true_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true * y_pred, 0, 1)))
    possible_positives = tf.reduce_sum(tf.round(tf.clip_by_value(y_true, 0, 1)))
    recall = true_positives / (possible_positives + tf.keras.backend.epsilon())
    return recall

def specificity_metric(y_true, y_pred):
    """Specificity metric"""
    true_negatives = tf.reduce_sum(tf.round(tf.clip_by_value((1-y_true) * (1-y_pred), 0, 1)))
    possible_negatives = tf.reduce_sum(tf.round(tf.clip_by_value(1-y_true, 0, 1)))
    specificity = true_negatives / (possible_negatives + tf.keras.backend.epsilon())
    return specificity

def f1_score(y_true, y_pred):
    """F1-Score metric"""
    precision = precision_metric(y_true, y_pred)
    recall = recall_metric(y_true, y_pred)
    return 2 * ((precision * recall) / (precision + recall + tf.keras.backend.epsilon()))

# Enhanced evaluation function
def comprehensive_evaluation(model, X_val, y_val, threshold=0.5):
    """Comprehensive evaluation with medical segmentation metrics"""
    
    print("=" * 70)
    print("COMPREHENSIVE MODEL EVALUATION - MEDICAL SEGMENTATION")
    print("=" * 70)
    
    # Get predictions
    y_pred = model.predict(X_val, verbose=0)
    y_pred_binary = (y_pred > threshold).astype(np.float32)
    
    # Flatten for overall metrics
    y_true_flat = y_val.flatten()
    y_pred_flat = y_pred_binary.flatten()
    
    # Calculate metrics
    val_loss = model.evaluate(X_val, y_val, verbose=0)[0]
    
    # Overall metrics
    overall_dice = dice_coef(
        tf.convert_to_tensor(y_val), 
        tf.convert_to_tensor(y_pred)
    ).numpy()
    
    overall_iou = iou_coef(
        tf.convert_to_tensor(y_val), 
        tf.convert_to_tensor(y_pred_binary)
    ).numpy()
    
    # Confusion matrix
    cm = confusion_matrix(y_true_flat, y_pred_flat)
    tn, fp, fn, tp = cm.ravel()
    
    # Calculate rates
    accuracy = (tp + tn) / (tp + tn + fp + fn)
    precision = tp / (tp + fp) if (tp + fp) > 0 else 0
    recall = tp / (tp + fn) if (tp + fn) > 0 else 0
    specificity = tn / (tn + fp) if (tn + fp) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0
    
    print(f"\nOVERALL PERFORMANCE METRICS:")
    print(f"   Loss: {val_loss:.4f}")
    print(f"   Dice Coefficient: {overall_dice:.4f}")
    print(f"   IoU (Jaccard): {overall_iou:.4f}")
    print(f"   F1-Score: {f1:.4f}")
    
    print(f"\nCLASSIFICATION METRICS:")
    print(f"   Accuracy: {accuracy:.4f}")
    print(f"   Precision: {precision:.4f}")
    print(f"   Recall (Sensitivity): {recall:.4f}") 
    print(f"   Specificity: {specificity:.4f}")
    
    print(f"\nCONFUSION MATRIX (Pixel-wise):")
    print(f"   True Negatives: {tn:,}")
    print(f"   False Positives: {fp:,}")
    print(f"   False Negatives: {fn:,}")
    print(f"   True Positives: {tp:,}")

    return {
        'loss': val_loss,
        'dice': overall_dice,
        'iou': overall_iou,
        'f1_score': f1,
        'precision': precision,
        'recall': recall,
        'specificity': specificity
    }


print("PERFORMING COMPREHENSIVE EVALUATION...")

# Load best model with enhanced metrics
print("Loading best model with enhanced metrics...")
best_model = tf.keras.models.load_model('best_multi_model.h5', 
    custom_objects={
        'combined_loss': combined_loss,
        'dice_coef': dice_coef,
        'dice_loss': dice_loss,
        'iou_coef': iou_coef,
        'precision_metric': precision_metric,
        'recall_metric': recall_metric,
        'specificity_metric': specificity_metric,
        'f1_score': f1_score
    }
)

# Run comprehensive evaluation
results = comprehensive_evaluation(best_model, X_val, y_val)
# Out:
# PERFORMING COMPREHENSIVE EVALUATION...
# Loading best model with enhanced metrics...
# ======================================================================
# COMPREHENSIVE MODEL EVALUATION - MEDICAL SEGMENTATION
# ======================================================================
#
# OVERALL PERFORMANCE METRICS:
#    Loss: 0.0870
#    Dice Coefficient: 0.9164
#    IoU (Jaccard): 0.8917
#    F1-Score: 0.9188
#
# CLASSIFICATION METRICS:
#    Accuracy: 0.9996
#    Precision: 0.9335
#    Recall (Sensitivity): 0.9045
#    Specificity: 0.9998
#
# CONFUSION MATRIX (Pixel-wise):
#    True Negatives: 62,042,282
#    False Positives: 10,026
#    False Negatives: 14,875
#    True Positives: 140,817

# %%
# Side By Side Visualization

def visualize_comparison(model, X_data, y_true, num_samples=3):
    """Simple side-by-side: MRI vs Ground Truth vs Prediction"""
    
    indices = np.random.choice(len(X_data), num_samples, replace=False)
    
    for i, idx in enumerate(indices):
        # Get data
        X_sample = X_data[idx]
        y_true_sample = y_true[idx]
        y_pred = model.predict(X_sample[np.newaxis, ...], verbose=0)[0]
        y_pred_binary = (y_pred > 0.5).astype(np.float32)
        
        # Use FLAIR channel as background
        background = X_sample[:, :, 0]
        
        # Create figure
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))
        
        # 1. Original MRI
        axes[0].imshow(background, cmap='gray')
        axes[0].set_title('Input MRI')
        axes[0].axis('off')
        
        # 2. Ground Truth (combine all tumor regions)
        axes[1].imshow(background, cmap='gray')
        # Create binary mask of all tumor regions
        gt_combined = np.any(y_true_sample > 0, axis=-1)
        axes[1].imshow(gt_combined, cmap='Reds', alpha=0.5)
        axes[1].set_title('Ground Truth')
        axes[1].axis('off')
        
        # 3. Prediction (combine all tumor regions)
        axes[2].imshow(background, cmap='gray')
        pred_combined = np.any(y_pred_binary > 0, axis=-1)
        axes[2].imshow(pred_combined, cmap='Reds', alpha=0.5)
        
        # Calculate Dice score
        dice = dice_coef(
            tf.convert_to_tensor(y_true_sample[np.newaxis, ...]),
            tf.convert_to_tensor(y_pred[np.newaxis, ...])
        ).numpy()
        
        axes[2].set_title(f'Prediction\nDice: {dice:.3f}')
        axes[2].axis('off')
        
        plt.suptitle(f'Sample {i+1}', fontsize=14, fontweight='bold')
        plt.tight_layout()
        plt.show()

# Execute
print("Generating side-by-side visualizations...")
visualize_comparison(best_model, X_val, y_val, num_samples=3)
# Out:
# Generating side-by-side visualizations...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_37/1764814826.py in <cell line: 0>()
#      52 # Execute
#      53 print("Generating side-by-side visualizations...")
# ---> 54 visualize_comparison(best_model, X_val, y_val, num_samples=3)
#
# NameError: name 'best_model' is not defined
